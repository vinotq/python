# %% [markdown]
# # **Lection #11**:
#
# ### **Theme**: Исключения
# ##### **Date**: 18.12.24

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import

class FlyWayMeta(type):
    def __new__(nmc, name, bases, attrs):
        attrs['fly'] = lambda self: print('fly')
        return type.__new__(nmc, name, bases, attrs)

    @abstractmethod
    def fly(self):
