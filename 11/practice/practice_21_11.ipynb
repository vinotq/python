# %% [markdown]
# # **Practice #n + 7**
# ##### 08.11.24

# %% [markdown]
# ### **Тема**: Патерны. Комбинация

# %% [markdown]
# ```mermaid
# classDiagram
#     class FinanceManager {
#         +addTransaction(Transaction)
#         +getTransactions() List~Transaction~
#         +getBalance() double
#     }
#
#     class TransactionFactory {
#         +createTransaction(amount, date, category) Transaction
#     }
#
#     class Transaction {
#         -amount: double
#         -date: Date
#         -category: String
#         +getAmount() double
#         +getDate() Date
#         +getCategory() String
#     }
#
#     class Category {
#         -name: String
#         +getName() String
#     }
#
#     class ReportGenerator {
#         +generateMonthlyReport(List~Transaction~) Report
#         +generateYearlyReport(List~Transaction~) Report
#     }
#
#     class Report {
#         -transactions: List~Transaction~
#         +getTransactions() List~Transaction~
#     }
#
#     FinanceManager "1" -- "1" TransactionFactory
#     FinanceManager "1" -- "*" Transaction
#     Transaction "1" -- "1" Category
#     FinanceManager "1" -- "1" ReportGenerator
#     ReportGenerator "1" -- "1" Report
# ```

# %%
from __future__ import annotations
from datetime import datetime


class Category:
    _categories = {}

    def __new__(cls, name):
        if name in Category._categories:
            return cls._categories[name]

        cat = super(Category, cls).__new__(cls)
        cls._categories[name] = cat
        return cat

    def __init__(self, name: str):
        if name in Category._categories:
            self = Category._categories[name]

        self.__name = name
        Category._categories[name] = self

    @property
    def name(self) -> str:
        return self.__name


class Transaction:
    def __init__(
        self, amount: float,
        date: datetime = datetime.now(),
        category: Category = Category("default")
    ):
        self.__amount = amount
        self.__date = date
        self.__category = category

    @property
    def amount(self) -> float:
        return self.__amount

    @property
    def date(self) -> datetime:
        return self.__date

    @property
    def category(self) -> Category:
        return self.__category


class Report:
    def __init__(self, transactions: list[Transaction]) -> None:
        self.__transactions = transactions

    @property
    def transactions(self) -> list[Transaction]:
        return self.__transactions

    def __str__(self):
        trans = []
        for tr in self.__transactions:
            s = f"{tr.amount} {tr.date} {tr.category.name}"
            trans.append(s)
        return "\n".join(trans)


class ReportGenerator():
    def generateReport(self, transactions: list[Transaction], specification: Specification) -> Report:
        res = []
        for tran in transactions:
            if specification.isSatisfied(tran):
                res.append(tran)
        return Report(res)


class Specification:
    def isSatisfied(self):
        pass


class MonthlySP(Specification):
    def __init__(self, month):
        self.specification = month

    def isSatisfied(self, transaction):
        return transaction.date.month == self.specification


class YearlySP(Specification):
    def __init__(self, year):
        self.specification = year

    def isSatisfied(self, transaction):
        return transaction.date.year == self.specification


class AndSP(Specification):
    def __init__(self, *args):
        self.specifications = args

    def isSatisfied(self, transaction):
        return all(spec.isSatisfied(transaction) for spec in self.specifications)


class TransactionFabric:
    pass


class FinanceManager:
    __transactionFabric = TransactionFabric()
    __reportGenerator = ReportGenerator()
    __transactions = []
    __balance = 0

    def __init__(self, transaction):
        self.transaction = transaction

    def addTransaction(self, transaction):
        self.transaction.append(transaction)

    def getTransaction(self):
        return self.transaction

    @property
    def getBalance(self):
        return sum(transaction.amount for transaction in self.transaction)

# %%
tr = Transaction(10)
tr2 = Transaction(10, category=Category("salary"))
tr3 = Transaction(10, category=Category("salary"))
rep = ReportGenerator().generateReport([tr, tr2, tr3], MonthlySP(11))
rep2 = ReportGenerator().generateReport([tr, tr2, tr3], MonthlySP(12))
rep3 = ReportGenerator().generateReport(
    [tr, tr2, tr3], AndSP(MonthlySP(11), YearlySP(2024)))
rep.transactions, rep2.transactions
rep3.transactions
# Out:
# [<__main__.Transaction at 0x7902244a2ae0>,
#  <__main__.Transaction at 0x7902244a33b0>,
#  <__main__.Transaction at 0x79022462a300>]

# %%
from copy import deepcopy


class FinanceManagerState:
    def __init__(self, balance, transactions):
        self.balance = balance
        self.transactions = deepcopy(transactions)


class Memento:
    __sate = None

    @classmethod
    def saveState(cls, manager: FinanceManager):
        cls.__sate = FinanceManagerState(manager.balance, manager.transactions)

    @classmethod
    def loadState(cls, manager: FinanceManager):
        return cls.__sate.transactions, cls.__sate.balance

# %%
from __future__ import annotations
from datetime import datetime


class FinanceManager:
    __reportGenerator = ReportGenerator()
    transactions = []
    __balance = 0

    @property
    def tranasactions(self):
        return self.__transactions

    @property
    def balance(self):
        return FinanceManager.__balance

    def addTransaction(self, amount, date, category):
        Memento.saveState(self)
        try:
            tran = Transaction(amount, date, category)
            self.__balance += amount
            self.transactions.append(tran)
        except Exception as e:  # noqa: E722
            self.tranasactions, self.balance = Memento.loadState()
            print(e)

            # raise Exception("Failed creating of new Transaction")

    def report(self):
        return self.__reportGenerator.generateReport(self.transactions, MonthlySP(11))


manager = FinanceManager()

tr = Transaction(10)
tr2 = Transaction(10, category=Category("salary"))
tr3 = Transaction(10, category=Category("salary"))
manager.addTransaction(10, datetime.now(), Category("salary"))
print(manager.report())
manager.addTransaction("10", datetime.now(), Category("boombastic"))
print(manager.report())
# Out:
# 10 2024-11-22 13:44:13.708590 salary
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 41
#      39 manager.addTransaction(10, datetime.now(), Category("salary"))
#      40 print(manager.report())
# ---> 41 manager.addTransaction("10", datetime.now(), Category("boombastic"))
#      42 print(manager.report())
#
# Cell In[24], line 19, in FinanceManager.addTransaction(self, amount, date, category)
#      18 def addTransaction(self, amount, date, category):
# ---> 19     Memento.saveState(self)
#      20     try:
#      21         tran = Transaction(amount, date, category)
#
# Cell In[23], line 15, in Memento.saveState(cls, manager)
#      13 @classmethod
#      14 def saveState(cls, manager: FinanceManager):
# ---> 15     cls.__sate = FinanceManagerState(manager.balance, manager.transactions)
#
# Cell In[23], line 7, in FinanceManagerState.__init__(self, balance, transactions)
#       5 def __init__(self, balance, transactions):
#       6     self.balance = balance
# ----> 7     self.transactions = deepcopy(transactions)
#
# File /usr/lib/python3.12/copy.py:136, in deepcopy(x, memo, _nil)
#     134 copier = _deepcopy_dispatch.get(cls)
#     135 if copier is not None:
# --> 136     y = copier(x, memo)
#     137 else:
#     138     if issubclass(cls, type):
#
# File /usr/lib/python3.12/copy.py:196, in _deepcopy_list(x, memo, deepcopy)
#     194 append = y.append
#     195 for a in x:
# --> 196     append(deepcopy(a, memo))
#     197 return y
#
# File /usr/lib/python3.12/copy.py:162, in deepcopy(x, memo, _nil)
#     160                 y = x
#     161             else:
# --> 162                 y = _reconstruct(x, memo, *rv)
#     164 # If is its own copy, don't memoize.
#     165 if y is not x:
#
# File /usr/lib/python3.12/copy.py:259, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     257 if state is not None:
#     258     if deep:
# --> 259         state = deepcopy(state, memo)
#     260     if hasattr(y, '__setstate__'):
#     261         y.__setstate__(state)
#
# File /usr/lib/python3.12/copy.py:136, in deepcopy(x, memo, _nil)
#     134 copier = _deepcopy_dispatch.get(cls)
#     135 if copier is not None:
# --> 136     y = copier(x, memo)
#     137 else:
#     138     if issubclass(cls, type):
#
# File /usr/lib/python3.12/copy.py:221, in _deepcopy_dict(x, memo, deepcopy)
#     219 memo[id(x)] = y
#     220 for key, value in x.items():
# --> 221     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     222 return y
#
# File /usr/lib/python3.12/copy.py:162, in deepcopy(x, memo, _nil)
#     160                 y = x
#     161             else:
# --> 162                 y = _reconstruct(x, memo, *rv)
#     164 # If is its own copy, don't memoize.
#     165 if y is not x:
#
# File /usr/lib/python3.12/copy.py:253, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     251 if deep and args:
#     252     args = (deepcopy(arg, memo) for arg in args)
# --> 253 y = func(*args)
#     254 if deep:
#     255     memo[id(x)] = y
#
# File /usr/lib/python3.12/copyreg.py:99, in __newobj__(cls, *args)
#      98 def __newobj__(cls, *args):
# ---> 99     return cls.__new__(cls, *args)
#
# TypeError: Category.__new__() missing 1 required positional argument: 'name'
