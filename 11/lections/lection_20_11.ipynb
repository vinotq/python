# %% [markdown]
# # **Lection #8**:
#
# ### **Theme**: Патерны 3, Структурные и начала поведенческих паттернов 😭😲🤯
#
# ##### **Date**: 20.11.24

# %% [markdown]
# ### **Паттерн** `Декоратор`
#
# - паттерн, _структурирующий_ объекты
# - добавляет объекту новые обязанности _динамически_

# %% [markdown]
# ### **Паттерн** `Приспособленец`
#
# - паттерн, _структурирующий_ объекты
# - разделение для эффективной поддержки множества мелких объектов
# - выносит общие св-ва объектов в новый и ссылается уже на него

# %% [markdown]
# ### **Паттерн** `Заместитель`
#
# - паттерн, _структурирующий_ объекты
# - контролирует доступ к объекту суррогатом которого он является
# - применяется, когда нужно получить доступ к объекту более изощренно

# %% [markdown]
# ### **Паттерн** `Заместитель`
#
# - паттерн, _структурирующий_ объекты
# - контролирует доступ к объекту суррогатом которого он является
# - применяется, когда нужно получить доступ к объекту более изощренно
# - к примеру, в БД на SQL, где нет как таковых прав доступа, `Proxy` будет промежуточным звеном проверки на права пользователя

# %% [markdown]
# # **Поведенческие паттерны**

# %% [markdown]
# #### Паттерны этого типа управляют обязанностями между объектами классов

# %% [markdown]
# ### **Паттерн** `Цепочка обязанностей`
#
# - паттерн поведения объектов
# - позволяет обработать запрос несколькими объектами, а не одному
# - к примеру, авторизация на сайте: много этапов проверки, часть которых можно скипнуть/заменить (к примеру - авторизация через Google)

# %% [markdown]
# ### **Паттерн** `Команда`
# - паттерн поведения объектов
# - инкапсулирует запрос в качестве объекта, может задавать параметры клиентов для обработки запросов, ставит их в очередь

# %% [markdown]
# ### **Паттерн** `Итератор`
# - паттерн поведения объектов
# - способ последовательного доступа ко всем элементам составного объекта, не раскрывая внутреннего представления

# %% [markdown]
# ### **Паттерн** `Посредник`
# - паттерн поведения объектов
# - обеспечивает отсутствие явных ссылок объектов друг на друга

# %% [markdown]
# ### **Паттерн** `Хранитель`
# - паттерн поведения объектов
# - не нарушая инкапсуляции, фикрисурет и выносит за пределы объекта его внутреннее состояние так, чтобы позднее можно было восстаносить объект в нем
