# %% [markdown]
# # **Lection #9**:
#
# ### **Theme**: Патерны 4, Поведенческие паттерны 😭😲🤯
#
# ##### **Date**: 27.11.24

# %% [markdown]
# ### **Паттерн** `Наблюдатель`
#
# - определяет зависимость типа "один ко многим" между объектами таким образом, что при изменении состояния одного оъекта все зависящие от него объекты тоже меняют состояние
#
# - ПРИМЕР: приложения следят за темой системы чтобы включить у себя такую же

# %% [markdown]
# ### **Паттерн** `Состояние`
# - Позволяет изменять свое поведение из-за внутреннего состояния
# - Создается впечатление, что объект стал объектом другого класса
# - Пример реализации - машина Тьюринга

# %% [markdown]
# ### **Паттерн** `Стратегия`
#
# - семейство алгоритммов, которые инкапсулированны в класс, и теперь они взаимозаменяемые
# - паттерн позволяет изменять алгоритмы независимо от клиента

# %% [markdown]
# ### **Паттерн** `Шаблонный метод`
#
# - определяет основу алгоритма и позволяет подклассам переопределить некоторые шаги алгоритма

# %% [markdown]
# ### **Паттерн** `Посетитель`
# - Описывает операцию, выполняемую с каждым объектом из некоторой структуры. Паттерн позволяет определить новую операцию, не изменяя классы этих объектов
#
# Используется когда:
# - в структуре объекты многих классов с различными интерфейсами и мы хотим выполнять над ними операции в зависимости от конкретных классов
