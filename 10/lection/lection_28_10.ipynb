# %% [markdown]
# # **Lection #6**:
# ### **Theme**: Патерны 😭😲🤯
# ##### **Date**: 28.10.24

# %% [markdown]
# ### **Паттерны** есть *шаблоны* решения задач
#
# ##### Каждый паттерн имеет **имя, описание, задачу и решение своей проблемы**:
# - **Задача** - описание того *как применять* паттерн
# - **Решение** - описание *элементов* дизайна
# - **Результат** - *следствия* применения паттерна
#
# ###

# %% [markdown]
# ### **Фундаментальные паттерны**:
# - **Интрерфейсы** - *метаклассы*
# - **Функциональный дизайн** - просто основа, как таковой *конкретной реализации не имеет*
# - **Делегирование** - передает *ответсвенность* выполнения своего поведения *на внешний связанный объект*
# - **Контейнер сво-в** - `setattr`
# - **Канал событий** - уведомления о конце выполнения команды - `wait`, `notify`
